# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Set the default figure size for all plots to 14x7 inches 
# and apply the 'fivethirtyeight' visual style for better aesthetics.
plt.rcParams['figure.figsize'] = (14, 7)
plt.style.use('fivethirtyeight')

# Import the display function to render objects (like Pandas DataFrames) 
# more cleanly and richly within Jupyter Notebook environments.
from IPython.display import display

# %%
# 1. Load the dataset into a DataFrame (replace 'your_file.csv' with your actual file path or name)
df = pd.read_csv('/workspaces/Machine-Learning-6-SIN-A-Mar-Jul-2026/penguins_size.csv')

# 2. Display the first 5 rows of the DataFrame to inspect the data structure
display(df.head())
# Out:
#   species     island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen              39.1             18.7              181.0
# 1  Adelie  Torgersen              39.5             17.4              186.0
# 2  Adelie  Torgersen              40.3             18.0              195.0
# 3  Adelie  Torgersen               NaN              NaN                NaN
# 4  Adelie  Torgersen              36.7             19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    MALE
# 1       3800.0  FEMALE
# 2       3250.0  FEMALE
# 3          NaN     NaN
# 4       3450.0  FEMALE

# %%
# 3. Retrieve the total number of rows and columns as a tuple (rows, columns)
shape = df.shape
# Print the final count of rows and columns in a clear format
print(f"The DataFrame has {shape[0]} rows and {shape[1]} columns.")
# Out:
# The DataFrame has 344 rows and 7 columns.

# %%
# Calculate the number of missing (null) values in each column.
null_counts = df.isnull().sum()

# Display the result to easily identify columns with missing data.
display(null_counts)
# Out:
# species               0
# island                0
# culmen_length_mm      2
# culmen_depth_mm       2
# flipper_length_mm     2
# body_mass_g           2
# sex                  10
# dtype: int64
