# %%
# Import pandas to handle data in tables (like Excel spreadsheets)
import pandas as pd

# Import numpy to perform fast mathematical operations on lists of numbers
import numpy as np 

# Import matplotlib to create graphs, charts, and visual plots
import matplotlib.pyplot as plt

# %%
# Loads the data file (CSV) and stores it in a table called 'unemployment'
unempoyment = pd.read_csv('/workspaces/Machine-Learning-6-SIN-A-Mar-Jul-2026/data/country_total.csv')

# %%
# Checks the data type of the variable to see what it is
type(unempoyment)
# Out:
# pandas.DataFrame

# %%
# Shows the first 5 rows of the data to get a quick preview
unempoyment.head()
# Out:
#   country seasonality    month  unemployment  unemployment_rate
# 0      at         nsa  1993.01        171000                4.5
# 1      at         nsa  1993.02        175000                4.6
# 2      at         nsa  1993.03        166000                4.4
# 3      at         nsa  1993.04        157000                4.1
# 4      at         nsa  1993.05        147000                3.9

# %%
# Returns the dimensions of the table (number of rows and columns)
unempoyment.shape
# Out:
# (20796, 5)

# %%
# Lists the names of all the columns (headers) in the table
unempoyment.columns
# Out:
# Index(['country', 'seasonality', 'month', 'unemployment', 'unemployment_rate'], dtype='str')

# %%
# Shows the data type of every column (e.g., numbers or text)
unempoyment.dtypes
# Out:
# country                  str
# seasonality              str
# month                float64
# unemployment           int64
# unemployment_rate    float64
# dtype: object

# %%
# Shows a statistical summary of the data (mean, min, max, etc.)
unempoyment.describe()
# Out:
#               month  unemployment  unemployment_rate
# count  20796.000000  2.079600e+04       19851.000000
# mean    1999.401290  7.900818e+05           8.179764
# std        7.483751  1.015280e+06           3.922533
# min     1983.010000  2.000000e+03           1.100000
# 25%     1994.090000  1.400000e+05           5.200000
# 50%     2001.010000  3.100000e+05           7.600000
# 75%     2006.010000  1.262250e+06          10.000000
# max     2010.120000  4.773000e+06          20.900000

# %%
# Creates a list of characters stored in a variable called 'my_list'
my_list = ['a', 'b', 'c', 'd', 'e', 'f']

# %%
# Gets all items from the 3rd element to the very end
my_list[2:]
# Out:
# ['c', 'd', 'e', 'f']

# %%
# Gets all items from the 3rd element to the very end
my_list[len(my_list)-4:]
# Out:
# ['c', 'd', 'e', 'f']

# %%
# new dataset countries.csv
dataset = pd.read_csv('/workspaces/Machine-Learning-6-SIN-A-Mar-Jul-2026/data/countries.csv')

# %%
dataset.head()

dataset.sample(5)

dataset.info()

dataset.shape

dataset['country_group'].value_counts()

dataset.describe()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 8 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   country              30 non-null     str
#  1   google_country_code  30 non-null     str
#  2   country_group        30 non-null     str
#  3   name_en              30 non-null     str
#  4   name_fr              30 non-null     str
#  5   name_de              30 non-null     str
#  6   latitude             30 non-null     float64
#  7   longitude            30 non-null     float64
# dtypes: float64(2), str(6)
# memory usage: 2.0 KB
#         latitude  longitude
# count  30.000000  30.000000
# mean   49.092609  14.324579
# std     7.956624  11.257010
# min    35.129141  -8.239122
# 25%    43.230916   6.979186
# 50%    49.238087  14.941462
# 75%    54.090400  23.351690
# max    64.950159  35.439795

# %%
# Gets the value at row 3 for that specific column
dataset.loc[3, 'google_country_code']
# Out:
# 'HR'

# %%
# Gets the first 5 rows (index 0 to 4) and all columns
dataset.loc[:4,:]
# Out:
#   country google_country_code country_group   name_en   name_fr     name_de  \
# 0      at                  AT            eu   Austria  Autriche  Österreich
# 1      be                  BE            eu   Belgium  Belgique     Belgien
# 2      bg                  BG            eu  Bulgaria  Bulgarie   Bulgarien
# 3      hr                  HR        non-eu   Croatia   Croatie    Kroatien
# 4      cy                  CY            eu    Cyprus    Chypre      Zypern
#
#     latitude  longitude
# 0  47.696554  13.345980
# 1  50.501045   4.476674
# 2  42.725674  25.482322
# 3  44.746643  15.340844
# 4  35.129141  33.428682

# %%
# Gets all rows and the first 4 columns
dataset.iloc[:,:4]
# Out:
#    country google_country_code country_group  \
# 0       at                  AT            eu
# 1       be                  BE            eu
# 2       bg                  BG            eu
# 3       hr                  HR        non-eu
# 4       cy                  CY            eu
# 5       cz                  CZ            eu
# 6       dk                  DK            eu
# 7       ee                  EE            eu
# 8       fi                  FI            eu
# 9       fr                  FR            eu
# 10      de                  DE            eu
# 11      gr                  GR            eu
# 12      hu                  HU            eu
# 13      ie                  IE            eu
# 14      it                  IT            eu
# 15      lv                  LV            eu
# 16      lt                  LT            eu
# 17      lu                  LU            eu
# 18      mt                  MT            eu
# 19      nl                  NL            eu
# ...

# %%
# Creates a new variable 'test' with rows 20 to 25 and all columns
test = dataset.loc[20:25, :]
test
# Out:
#    country google_country_code country_group   name_en    name_fr    name_de  \
# 20      no                  NO        non-eu    Norway    Norvège   Norwegen
# 21      pl                  PL            eu    Poland    Pologne      Polen
# 22      pt                  PT            eu  Portugal   Portugal   Portugal
# 23      ro                  RO            eu   Romania   Roumanie   Rumänien
# 24      sk                  SK            eu  Slovakia  Slovaquie   Slowakei
# 25      si                  SI            eu  Slovenia   Slovénie  Slowenien
#
#      latitude  longitude
# 20  64.556460  12.665766
# 21  51.918907  19.134334
# 22  39.558069  -7.844941
# 23  45.942611  24.990152
# 24  48.672644  19.700032
# 25  46.149259  14.986617

# %%
# Filters the table to show only rows where the country group is 'non-eu'
test[test['country_group'] == 'non-eu']
# Out:
#    country google_country_code country_group name_en  name_fr   name_de  \
# 20      no                  NO        non-eu  Norway  Norvège  Norwegen
#
#     latitude  longitude
# 20  64.55646  12.665766

# %%
# Filters the table to show only countries with a longitude greater than 25
dataset[dataset['longitude']>25]
# Out:
#    country google_country_code country_group   name_en   name_fr    name_de  \
# 2       bg                  BG            eu  Bulgaria  Bulgarie  Bulgarien
# 4       cy                  CY            eu    Cyprus    Chypre     Zypern
# 7       ee                  EE            eu   Estonia   Estonie    Estland
# 8       fi                  FI            eu   Finland  Finlande   Finnland
# 28      tr                  TR        non-eu    Turkey   Turquie     Türkei
#
#      latitude  longitude
# 2   42.725674  25.482322
# 4   35.129141  33.428682
# 7   58.592469  25.806950
# 8   64.950159  26.067564
# 28  38.952942  35.439795
